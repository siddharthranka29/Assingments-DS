# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
data=pd.read_csv("D:\\Alphabets_data.csv")
data
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %%
#Data Exploration and Preprocessing
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
data.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
data.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
data.hist(bins=20,figsize=(15,11))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
le=LabelEncoder()

# %%
data['letter']=le.fit_transform(data['letter'])

# %%
features=data.drop('letter',axis=1)

# %%
se=StandardScaler()
se.fit_transform(features)
# Out:
# array([[-1.0576983 ,  0.29187713, -1.05327668, ..., -0.21908163,
#         -1.4381527 ,  0.12291107],
#        [ 0.51038497,  1.5023577 , -1.05327668, ..., -0.21908163,
#          0.12008142,  1.35944092],
#        [-0.01230945,  1.19973756,  0.43590966, ..., -0.8656262 ,
#         -0.26947711,  0.74117599],
#        ...,
#        [ 1.03307939,  0.59449727,  0.43590966, ...,  2.36709667,
#         -0.65903564, -2.35014863],
#        [-1.0576983 , -1.22122359, -0.55688123, ...,  0.42746295,
#          0.50963994,  0.12291107],
#        [-0.01230945,  0.59449727,  0.43590966, ..., -0.8656262 ,
#         -0.65903564,  0.12291107]])

# %%
target=data['letter']

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Model Implementation

from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1,activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,validation_split=0.33,epochs=20,batch_size=20)
# Out:
# Epoch 1/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.0369 - loss: -258644.8594 - val_accuracy: 0.0411 - val_loss: -1063532.1250
# Epoch 2/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -3984536.0000 - val_accuracy: 0.0411 - val_loss: -8338010.5000
# Epoch 3/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -16155443.0000 - val_accuracy: 0.0411 - val_loss: -25824728.0000
# Epoch 4/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -39750692.0000 - val_accuracy: 0.0411 - val_loss: -55669756.0000
# Epoch 5/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -76535168.0000 - val_accuracy: 0.0411 - val_loss: -99342960.0000
# Epoch 6/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -127753952.0000 - val_accuracy: 0.0411 - val_loss: -157961488.0000
# Epoch 7/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -194547920.0000 - val_accuracy: 0.0411 - val_loss: -232713264.0000
# Epoch 8/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -277761920.0000 - val_accuracy: 0.0411 - val_loss: -323963360.0000
# Epoch 9/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0369 - loss: -378034560.0000 - val_accuracy: 0.0411 - val_loss: -432712832.0000
# Epoch 10/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -496456768.0000 - val_accuracy: 0.0411 - val_loss: -560102784.0000
# Epoch 11/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -634015680.0000 - val_accuracy: 0.0411 - val_loss: -707032768.0000
# Epoch 12/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -791327488.0000 - val_accuracy: 0.0411 - val_loss: -874058688.0000
# Epoch 13/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -969573312.0000 - val_accuracy: 0.0411 - val_loss: -1062413888.0000
# Epoch 14/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -1169306880.0000 - val_accuracy: 0.0411 - val_loss: -1272301312.0000
# Epoch 15/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.0369 - loss: -1392060544.0000 - val_accuracy: 0.0411 - val_loss: -1506273536.0000
# Epoch 16/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -1638355200.0000 - val_accuracy: 0.0411 - val_loss: -1763521792.0000
# Epoch 17/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -1909138816.0000 - val_accuracy: 0.0411 - val_loss: -2046165376.0000
# Epoch 18/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -2205957120.0000 - val_accuracy: 0.0411 - val_loss: -2354978560.0000
# Epoch 19/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -2528965120.0000 - val_accuracy: 0.0411 - val_loss: -2690226944.0000
# Epoch 20/20
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0369 - loss: -2878854912.0000 - val_accuracy: 0.0411 - val_loss: -3052559360.0000

# %%
score=model.evaluate(x_train,y_train)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0383 - loss: -3059736320.0000

# %%
score
# Out:
# [-3059736320.0, 0.03831249848008156]

# %%
#Hyperparameter Tuning

import tensorflow as tf
from kerastuner import RandomSearch

def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units1', min_value=32, max_value=128, step=16), activation='relu', input_shape=(x_train.shape[1],)))
    model.add(Dense(units=hp.Int('units2', min_value=16, max_value=64, step=16), activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(build_model, objective='val_accuracy', max_trials=5, executions_per_trial=3, directory='my_dir', project_name='alphabet_tuning')

tuner.search(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Reloading Tuner from my_dir\alphabet_tuning\tuner0.json

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best units1: {best_hps.get('units1')}, Best units2: {best_hps.get('units2')}, Best learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Best units1: 80, Best units2: 16, Best learning_rate: 0.01

# %%
best_model = tuner.hypermodel.build(best_hps)

# %%
best_model.fit(x_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 11/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 12/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 13/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 14/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 15/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 16/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 17/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 18/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 19/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 20/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 21/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 22/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 23/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 24/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 25/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 26/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 27/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 28/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 29/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 30/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 31/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 32/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0371 - loss: 0.0000e+00 - val_accuracy: 0.0431 - val_loss: 0.0000e+00

# %%
#Evaluation

test_loss, test_accuracy = best_model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0382 - loss: 0.0000e+00
# Test Accuracy: 0.03824999928474426
